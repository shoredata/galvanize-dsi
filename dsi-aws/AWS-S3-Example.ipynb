# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_cancer = pd.read_csv('https://s3-us-west-2.amazonaws.com/garden.shelbysoft.com/cancer.csv')

# %%
df_cancer
# Out:
#      cancer  population
# 0       1.0       445.0
# 1       0.0       559.0
# 2       3.0       677.0
# 3       4.0       681.0
# 4       3.0       746.0
# 5       4.0       869.0
# 6       1.0       950.0
# 7       5.0       976.0
# 8       5.0      1096.0
# 9       5.0      1098.0
# 10      5.0      1114.0
# 11      7.0      1125.0
# 12      5.0      1236.0
# 13      6.0      1285.0
# 14      3.0      1291.0
# 15      3.0      1318.0
# 16      2.0      1323.0
# 17      8.0      1327.0
# 18      9.0      1438.0
# 19      7.0      1479.0
# 20      4.0      1536.0
# 21      6.0      1598.0
# 22      6.0      1635.0
# 23     11.0      1667.0
# 24      4.0      1696.0
# 25      7.0      1792.0
# 26      7.0      1795.0
# 27      4.0      1808.0
# 28      6.0      1838.0
# 29     16.0      1838.0
# ..      ...         ...
# 271   111.0     26245.0
# 272   103.0     26408.0
# 273   117.0     26691.0
# 274   118.0     28024.0
# 275    40.0     28270.0
# 276    83.0     28477.0
# ...

# %%
df_cancer['cancer_rate'] = df_cancer['cancer'] / df_cancer['population']

# %%
df_cancer
# Out:
#      cancer  population  cancer_rate
# 0       1.0       445.0     0.002247
# 1       0.0       559.0     0.000000
# 2       3.0       677.0     0.004431
# 3       4.0       681.0     0.005874
# 4       3.0       746.0     0.004021
# 5       4.0       869.0     0.004603
# 6       1.0       950.0     0.001053
# 7       5.0       976.0     0.005123
# 8       5.0      1096.0     0.004562
# 9       5.0      1098.0     0.004554
# 10      5.0      1114.0     0.004488
# 11      7.0      1125.0     0.006222
# 12      5.0      1236.0     0.004045
# 13      6.0      1285.0     0.004669
# 14      3.0      1291.0     0.002324
# 15      3.0      1318.0     0.002276
# 16      2.0      1323.0     0.001512
# 17      8.0      1327.0     0.006029
# 18      9.0      1438.0     0.006259
# 19      7.0      1479.0     0.004733
# 20      4.0      1536.0     0.002604
# 21      6.0      1598.0     0.003755
# 22      6.0      1635.0     0.003670
# 23     11.0      1667.0     0.006599
# ...

# %%
plt.hist(df_cancer['cancer_rate'], 33)
# Out:
# (array([ 1.,  0.,  0.,  2.,  2.,  5.,  7., 12., 17., 16., 16., 24., 28.,
#         29., 24., 35., 19., 18., 11., 10.,  8.,  4.,  4.,  4.,  1.,  2.,
#          0.,  0.,  0.,  1.,  0.,  0.,  1.]),
#  array([0.        , 0.00026379, 0.00052758, 0.00079137, 0.00105517,
#         0.00131896, 0.00158275, 0.00184654, 0.00211033, 0.00237412,
#         0.00263791, 0.0029017 , 0.0031655 , 0.00342929, 0.00369308,
#         0.00395687, 0.00422066, 0.00448445, 0.00474824, 0.00501204,
#         0.00527583, 0.00553962, 0.00580341, 0.0060672 , 0.00633099,
#         0.00659478, 0.00685857, 0.00712237, 0.00738616, 0.00764995,
#         0.00791374, 0.00817753, 0.00844132, 0.00870511]),
#  <a list of 33 Patch objects>)

# %%
plt.hist(df_cancer['cancer_rate'], 33)
plt.savefig('cancer_rate.png')

# %%
pd.DataFrame(df_cancer['cancer_rate']).to_csv('cancer_rate.csv')
